# %%
import pandas as pd
import numpy as np

# %%
from sklearn import metrics

# %%
data=pd.read_csv("problem_2/problem_2_train.csv")

# %%
pd.set_option('display.max_columns',500)

# %% [markdown]
# # what type of  data is

# %%
data.head()
# Out:
#       srno mobmake  hubid  hubpincode  pickuppartnerid  deliverypartnerid  \
# 0  2851218      AN      7      500004              233                233
# 1  2838330      AJ     10      226010              233                233
# 2  2835781      AJ      2      110018              233                233
# 3  2838589      AM      2      110018              233                233
# 4  2855214      AN     21      110015              233                233
#
#    insuranceCompanyId custpincodecategory claimtype  custpincode  \
# 0                 131                   A      ADLD       500001
# 1                 131                   A      ADLD       226022
# 2                 228                   A      ADLD       110018
# 3                 228                   B      ADLD       124001
# 4                 131                   A      ADLD       201301
#
#   memcreateddate mobilepurchasedate claimintdate  servicecntrid  \
# ...

# %%
data.columns
# Out:
# Index(['srno', 'mobmake', 'hubid', 'hubpincode', 'pickuppartnerid',
#        'deliverypartnerid', 'insuranceCompanyId', 'custpincodecategory',
#        'claimtype', 'custpincode', 'memcreateddate', 'mobilepurchasedate',
#        'claimintdate', 'servicecntrid', 'pickupStartdate', 'tat_in_days'],
#       dtype='object')

# %% [markdown]
# # Data analysing

# %%
data.describe()
# Out:
#                srno        hubid     hubpincode  pickuppartnerid  \
# count  6.250000e+03  6250.000000    6250.000000      6250.000000
# mean   2.946134e+06    11.732000  340546.139840       232.654400
# std    7.733480e+04     9.141463  213449.097822        30.471658
# min    2.818359e+06     0.000000       0.000000         0.000000
# 25%    2.877226e+06     3.000000  110018.000000       233.000000
# 50%    2.944426e+06     8.000000  400001.000000       233.000000
# 75%    3.012237e+06    21.000000  500004.000000       233.000000
# max    3.101035e+06    27.000000  800001.000000       308.000000
#
#        deliverypartnerid  insuranceCompanyId    custpincode  servicecntrid  \
# count        6250.000000         6250.000000    6250.000000    6250.000000
# mean          231.495360          155.040480  366009.473440    4457.158080
# std            22.521945           41.883918  210990.167946     200.945634
# min             0.000000          131.000000       0.000000    4008.000000
# ...

# %% [markdown]
# # label encoding

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
data['custpincodecategory'] = le.fit_transform(data['custpincodecategory'])
data['mobmake'] = le.fit_transform(data['mobmake'])
data['claimtype'] = le.fit_transform(data['claimtype'])

# %%
data.head()
# Out:
#       srno  mobmake  hubid  hubpincode  pickuppartnerid  deliverypartnerid  \
# 0  2851218       12      7      500004              233                233
# 1  2838330        8     10      226010              233                233
# 2  2835781        8      2      110018              233                233
# 3  2838589       11      2      110018              233                233
# 4  2855214       12     21      110015              233                233
#
#    insuranceCompanyId  custpincodecategory  claimtype  custpincode  \
# 0                 131                    1          0       500001
# 1                 131                    1          0       226022
# 2                 228                    1          0       110018
# 3                 228                    2          0       124001
# 4                 131                    1          0       201301
#
#   memcreateddate mobilepurchasedate claimintdate  servicecntrid  \
# ...

# %%
data.head()
# Out:
#       srno  mobmake  hubid  hubpincode  pickuppartnerid  deliverypartnerid  \
# 0  2851218       12      7      500004              233                233
# 1  2838330        8     10      226010              233                233
# 2  2835781        8      2      110018              233                233
# 3  2838589       11      2      110018              233                233
# 4  2855214       12     21      110015              233                233
#
#    insuranceCompanyId  custpincodecategory  claimtype  custpincode  \
# 0                 131                    1          0       500001
# 1                 131                    1          0       226022
# 2                 228                    1          0       110018
# 3                 228                    2          0       124001
# 4                 131                    1          0       201301
#
#   memcreateddate mobilepurchasedate claimintdate  servicecntrid  \
# ...

# %% [markdown]
# # Adding new columns

# %%
data['sub9']=data.pickuppartnerid-data.deliverypartnerid

# %%
data['sub']=abs(data.hubpincode-data.custpincode)

# %%
data.head()
# Out:
#       srno  mobmake  hubid  hubpincode  pickuppartnerid  deliverypartnerid  \
# 0  2851218       12      7      500004              233                233
# 1  2838330        8     10      226010              233                233
# 2  2835781        8      2      110018              233                233
# 3  2838589       11      2      110018              233                233
# 4  2855214       12     21      110015              233                233
#
#    insuranceCompanyId  custpincodecategory  claimtype  custpincode  \
# 0                 131                    1          0       500001
# 1                 131                    1          0       226022
# 2                 228                    1          0       110018
# 3                 228                    2          0       124001
# 4                 131                    1          0       201301
#
#   memcreateddate mobilepurchasedate claimintdate  servicecntrid  \
# ...

# %%
#data['sub']=pd.to_numeric(data['sub'])

# %%
#data['sub'] = data['sub'].apply(lambda x: x**2)

# %%
#data.claimintdate=pd.to_datetime(data.claimintdate)

# %%
#data.mobilepurchasedate=pd.to_datetime(data.mobilepurchasedate)

# %%
#data['subd']=abs((data.mobilepurchasedate-data.claimintdate))

# %% [markdown]
# # taking columns for algorithm

# %%
data['mobmake'].astype(int)
# Out:
# 0       12
# 1        8
# 2        8
# 3       11
# 4       12
# 5       12
# 6       17
# 7       17
# 8       12
# 9        8
# 10      12
# 11      12
# 12      17
# 13       7
# 14       3
# 15      31
# 16       8
# 17      12
# 18      17
# 19       8
# 20       8
# 21       3
# 22       3
# 23      12
# 24      12
# 25      17
# 26      12
# 27       1
# 28      11
# 29       8
# 30       1
# 31       8
# 32      17
# 33      12
# 34       8
# 35      17
# 36       3
# 37      36
# 38      12
# 39       8
# 40       8
# 41       7
# 42      12
# 43      12
# 44       8
# 45      17
# 46       8
# 47      12
# 48      17
# 49      12
# 50      12
# 51      12
# 52      17
# 53      31
# 54      17
# 55      12
# 56      17
# 57      17
# 58      12
# 59       8
# 60       3
# 61      12
# 62       4
# 63      12
# 64       8
# 65       8
# 66       1
# 67       8
# 68      12
# 69       1
# 70      17
# 71      18
# 72      17
# 73      33
# 74      31
# 75      17
# ...

# %%
feat=['mobmake','hubid','insuranceCompanyId','custpincodecategory','claimtype','servicecntrid','sub']

# %%
X=data[feat]
y=data['tat_in_days']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
linreg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# 12.679965863025389
# [ 0.53032892 -0.34584205 -0.18888745  0.80290481  0.43854466 -0.68639757
#   1.03820207]

# %%
list(zip(feat,linreg.coef_))
# Out:
# [('mobmake', 0.5303289206195545),
#  ('hubid', -0.3458420508514075),
#  ('insuranceCompanyId', -0.18888744850542402),
#  ('custpincodecategory', 0.8029048113600364),
#  ('claimtype', 0.438544664146692),
#  ('servicecntrid', -0.6863975693893408),
#  ('sub', 1.0382020671188865)]

# %%
y_pred=linreg.predict(X_test)

# %%
np.sqrt(metrics.mean_squared_error(y_pred,y_test))
# Out:
# 4.960105061221082

# %% [markdown]
# # train the data on complete train file

# %%
data.describe()
# Out:
#                srno      mobmake        hubid     hubpincode  pickuppartnerid  \
# count  6.250000e+03  6250.000000  6250.000000    6250.000000      6250.000000
# mean   2.946134e+06    12.208480    11.732000  340546.139840       232.654400
# std    7.733480e+04     5.926597     9.141463  213449.097822        30.471658
# min    2.818359e+06     0.000000     0.000000       0.000000         0.000000
# 25%    2.877226e+06     8.000000     3.000000  110018.000000       233.000000
# 50%    2.944426e+06    12.000000     8.000000  400001.000000       233.000000
# 75%    3.012237e+06    16.750000    21.000000  500004.000000       233.000000
# max    3.101035e+06    37.000000    27.000000  800001.000000       308.000000
#
#        deliverypartnerid  insuranceCompanyId  custpincodecategory  \
# count        6250.000000         6250.000000          6250.000000
# mean          231.495360          155.040480             1.432000
# std            22.521945           41.883918             0.787728
# ...

# %%
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
linreg.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
test=pd.read_csv("problem_2/problem_2_test.csv")

# %%
test.head()
# Out:
#       srno mobmake  hubid  hubpincode  pickuppartnerid  deliverypartnerid  \
# 0  2829088      AN      3      560011              233                233
# 1  2829866      AJ      2      110018              233                233
# 2  2894489      AJ      3      560011              233                233
# 3  2876708      AJ      2      110018              233                233
# 4  2890283      AN     22      400104              233                233
#
#    insuranceCompanyId custpincodecategory claimtype  custpincode  \
# 0                 131                   A      ADLD       560093
# 1                 228                   A      ADLD       110034
# 2                 228                   C      ADLD       590014
# 3                 228                   B      ADLD       250110
# 4                 131                   C      ADLD       496001
#
#   memcreateddate mobilepurchasedate claimintdate  servicecntrid  \
# ...

# %%
#feat=['mobmake','hubid','insuranceCompanyId','custpincodecategory','claimtype','servicecntrid','sub']

# %%
test['custpincodecategory'] = le.fit_transform(test['custpincodecategory'])
test['mobmake'] = le.fit_transform(test['mobmake'])
test['claimtype'] = le.fit_transform(test['claimtype'])

# %%
test['sub']=abs(data.hubpincode-data.custpincode)

# %%
test['mobmake'].astype(int)
# Out:
# 0       13
# 1       10
# 2       10
# 3       10
# 4       13
# 5       15
# 6       15
# 7       30
# 8       13
# 9       13
# 10      21
# 11      13
# 12      10
# 13      19
# 14       4
# 15      10
# 16      13
# 17      15
# 18      13
# 19      15
# 20      10
# 21      10
# 22      13
# 23      10
# 24      13
# 25       6
# 26      13
# 27      13
# 28      15
# 29      13
# 30       9
# 31       6
# 32      13
# 33      16
# 34      13
# 35      15
# 36      13
# 37      15
# 38      13
# 39      10
# 40      13
# 41      13
# 42      10
# 43      10
# 44       9
# 45      13
# 46      10
# 47      10
# 48      10
# 49      13
# 50      13
# 51      10
# 52      28
# 53       5
# 54      12
# 55      32
# 56      10
# 57      13
# 58      10
# 59      13
# 60      13
# 61      10
# 62      13
# 63       5
# 64      13
# 65      13
# 66      10
# 67      13
# 68      13
# 69      10
# 70      13
# 71      13
# 72      15
# 73      13
# 74      15
# 75      13
# ...

# %%
Xtest=test[feat]

# %%
y_pred=linreg.predict(Xtest)

# %%
print(y_pred)
# Out:
# [12.32239614 11.85157751 13.55286897 ... 12.02368609 11.20888954
#  12.27007209]

# %%
test['tat_in_days']=y_pred

# %%
test.to_csv('sol2.csv')
